# %%
import pandas as pd
import os 
import re

# %%
raw_df = pd.read_csv(os.getcwd()+'/data/raw_data.csv')

# %%
body_df = raw_df[raw_df.type=='body']

# %%
body_df[[ "[COURSE1]" not in i for i in body_df.body]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 body_df[[ ("[COURSE1]" not in i) for i in body_df.body]]
#
# Cell In[67], line 1, in <listcomp>(.0)
# ----> 1 body_df[[ ("[COURSE1]" not in i) for i in body_df.body]]
#
# TypeError: argument of type 'float' is not iterable

# %%
comment_df = raw_df[(raw_df.type=='comment') & 
                    (raw_df.writer.isin(['Kitchen B1','kitchen B1']))]
soldout_df= comment_df[["품절" in i for i in comment_df.body]]

# %%
soldout_df[[ ("1코너" not in i) & 
             ("1코스" not in i) &
             ("2코너" not in i) & 
             ("2코스" not in i) for i in soldout_df.body]]
# Out:
#        post_no     type      writer  \
# 322  926901390  comment  Kitchen B1
# 713  926901651  comment  Kitchen B1
# 839  926901723  comment  Kitchen B1
#
#                                                   body            time
# 322  샐러드바 현미밥 품절되어 추가조리 중입니다\n고객님께 이용에 불편을 드려 대단히 죄...     2023년 9월 5일
# 713                          코너 품절로 추가찬 풀무원조미김이 제공됩니다.   2월 1일 오후 1:22
# 839                     느타리버섯볶음이 품절되어 비엔나소시지볶음이 제공됩니다.  3월 14일 오후 1:20

# %%
strings = ["aString", "yetAnotherString", "evenAnotherOne"]

["String" in i for i in strings]
# Out:
# [True, True, False]

# %%
body_df.body[102]
# Out:
# '[COURSE1]\n맑은소고기무국, 잡곡밥, 바싹김치전,\n데리야끼미트볼조림, 무말랭이무침\n740kcal(단백질:25g)Na함량:1229mg(염도:0.6%)\n[샐러드바]\n그린샐러드, 살사푸실리샐러드, 식혜,\n현미밥/백미밥, 포기김치/열무김치'

# %%
#strings = ["Important text,      !Comment that could be removed", "Other String"]
[re.sub("\n", "", x) for x in body_df.body]
# Out:
# ['[COURSE1]투움바파스타, 미니함박&데미소스,오이피클, 탄산음료956kcal(단백질:36g)Na함량:1270mg(염도:0.6%)[COURSE2]닭곰탕, 잡곡밥,언양식불고기, 쥐어채볶음, 고들빼기무침882kcal(단백질:44g)Na함량:1245mg(염도:0.6%)[샐러드바]그린샐러드, 과일푸딩, 매작과,현미밥/백미밥,포기김치/깍두기',
#  '[COURSE1]육감쫄면, 우동국물,후리가케밥(소), 갈비만두찜, 꼬들단무지942kcal(단백질:58g)Na함량:1466mg(염도:0.5%)[COURSE2]차돌된장찌개, 잡곡밥, 한식잡채,고구마순들깨나물, 청경채겉절이631kcal(단백질:37g)Na함량:1429mg(염도:0.7%)[샐러드바]그린샐러드,코울슬로샐러드, 버터쿠키,현미밥/백미밥,포기김치/석박지',
#  '[COURSE1]<제철식재> 매실매실청돈육불고기, 잡곡밥, 얼큰콩나물국, 느타리버섯채소볶음, 양념깻잎지699kcal(단백질:30g)Na함량:1251mg(염도:0.6%)[COURSE2]<제철식재> 표고버섯새우볶음밥&짜장소스, 계란파국, 표고돈육탕수육, 중국식오이무침916kcal(단백질:41g)Na함량:1411mg(염도:0.5%)[샐러드바]그린샐러드,렌틸콩유자샐러드, 식혜,현미밥/백미밥,배추겉절이/깍두기',
#  '[COURSE1]경상도식소고기무국, 잡곡밥, 녹두빈대떡,부들어묵볶음, 삼색겨자냉채768kcal(단백질:39g)Na함량:1442mg(염도:0.6%)[COURSE2]스팸마요덮밥, 미역국,순살닭강정&알새우칩, 블루베리무피클986kcal(단백질:55g)Na함량:1226mg(염도:0.6%)[샐러드바]그린샐러드, 방울토마토, 건빵튀김,현미밥/백미밥, 포기김치/깍두기',
# ...
